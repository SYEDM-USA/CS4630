# %%
#2 Access NCBI (Gov site) over the web
#Query for a specific term in NCBI database and spit out the response

#http://biopython.org/DIST/docs/tutorial/Tutorial.html#chapter:entrez
#9.14.2 example 
#Package Entrez: Integrates several health sciences databases at (NCBI). 
#Can search many datasets such as 
#PubMed, DNA and protein sequence databases, 3D protein structure and protein 

#EGQuery - find out the number of results we get before downloading them
from Bio import Entrez
from Bio import SeqIO
from Bio import Entrez

Entrez.email = "kresman@bgsu.edu"     # Tell NCBI who you are
handle = Entrez.egquery(term="Cypripedioideae")
handle = Entrez.efetch(db="pubmed",id="31811259", retmode="xml")
record = Entrez.read(handle)
print (type (record))
#curious what this record is?
print (record)
# Out:
# <class 'Bio.Entrez.Parser.StructureElement'>
# ...
